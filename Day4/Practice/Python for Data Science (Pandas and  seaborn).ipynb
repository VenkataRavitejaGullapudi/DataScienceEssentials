# %% [markdown]
# **Pandas**
#
# *Series:*
# 1D array and similar to numpy array
#
#
# *Dataframe:*
# Most useful datastructures to represent the data.
# Stored in2D form

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.1.4

# %%
# Series

population_dict = {
    "California": 38335215,
    "Texas": 19642455,
    "New york":31243256,
    "Florida":1312435,
    "Illinois":23423265462
}
print(population_dict)
type(population_dict)
# Out:
# {'California': 38335215, 'Texas': 19642455, 'New york': 31243256, 'Florida': 1312435, 'Illinois': 23423265462}
# dict

# %%
population = pd.Series(population_dict)
population
# Out:
# California       38335215
# Texas            19642455
# New york         31243256
# Florida           1312435
# Illinois      23423265462
# dtype: int64

# %%
type(population)
# Out:
# pandas.core.series.Series

# %%
population[0]
# Out:
# 38335215

# %%
population['California']
# Out:
# 38335215

# %%
population[0:3]
# Out:
# California    38335215
# Texas         19642455
# New york      31243256
# dtype: int64

# %%
population['California':'Florida']
# Out:
# California    38335215
# Texas         19642455
# New york      31243256
# Florida        1312435
# dtype: int64

# %% [markdown]
# From the above 2 cells we can see that Explicit indices start from start index and end at end index.
# And implicit indices start from start index and end at end-1 index.

# %%
pd.Series(25)
# Out:
# 0    25
# dtype: int64

# %%
pd.Series(25,index=['Ravi'])
# Out:
# Ravi    25
# dtype: int64

# %%
# In this case it cause broadcasting
s = pd.Series(25,index=[111,222,333])
s
# Out:
# 111    25
# 222    25
# 333    25
# dtype: int64

# %%
#s[0] # gives error as index not found
# this is because when we use the numbers as index
# and we tried to access data using indexing operation
# by default it uses explicit index and when we tried to access data 
# using slicing it uses implicit index 
s[111]
# Out:
# 25

# %%
pd.Series({2:'a',1:'b',3:'c'})
# Out:
# 2    a
# 1    b
# 3    c
# dtype: object

# %%
# only the indices specified in the index ist will be shown
pd.Series({2:'a',1:'b',3:'c'},index=[3,2])
# Out:
# 3    c
# 2    a
# dtype: object

# %%
type(population)
population
# Out:
# California       38335215
# Texas            19642455
# New york         31243256
# Florida           1312435
# Illinois      23423265462
# dtype: int64

# %%
pd.DataFrame(population)
# Out:
#                       0
# California     38335215
# Texas          19642455
# New york       31243256
# Florida         1312435
# Illinois    23423265462

# %%
pd.DataFrame(population,columns=['population'])
# Out:
#              population
# California     38335215
# Texas          19642455
# New york       31243256
# Florida         1312435
# Illinois    23423265462

# %%
data = [{'a':i, 'b':2*i} for i in range(3)]
df = pd.DataFrame(data)
df
# Out:
#    a  b
# 0  0  0
# 1  1  2
# 2  2  4

# %%
df.columns= ['Col1','Col2']
df
# Out:
#    Col1  Col2
# 0     0     0
# 1     1     2
# 2     2     4

# %%
df.index = ['X','Y','Z']
df
# Out:
#    Col1  Col2
# X     0     0
# Y     1     2
# Z     2     4

# %%
list(df.columns)
# Out:
# ['Col1', 'Col2']

# %% [markdown]
# **Indexers: loc and iloc**

# %%
data  = pd.Series(['a','b','c'], index=[1,3,5])
data
# Out:
# 1    a
# 3    b
# 5    c
# dtype: object

# %% [markdown]
# When we use the numbers as explicit index then by default the explicit index is used in indexing operation and when slicing operation implicit index is used. So to overcome this confusion we use iloc and loc.

# %%
# Slicing -> pandas uses Implicit index
print(data[1:3])
# Indexing -> pandas uses Explicit index
data[1]
# Out:
# 3    b
# 5    c
# dtype: object
# 'a'

# %%
#  implicit index
data.loc[1:3]
# Out:
# 1    a
# 3    b
# dtype: object

# %%
# explicit index
data[1]
# Out:
# 'a'

# %%
# implicit index index loc
data.iloc[1]
# Out:
# 'b'

# %%
#implicit
data.iloc[1:3]
# Out:
# 3    b
# 5    c
# dtype: object

# %%
data = pd.read_csv("/content/drive/My Drive/Colab Notebooks/LETS_UPGRADE/students.csv");
data.head()
# Out:
#          id first_name last_name  ...    ged english_2nd_language first_generation
# 0  111111.0       John       Doe  ...  False                False             True
# 1  111112.0       Jane     Smith  ...  False                False             True
# 2  111113.0      Sarah    Thomas  ...  False                False            False
# 3  111114.0      Frank     Brown  ...   True                False             True
# 4  111115.0       Mike     Davis  ...  False                 True            False
#
# [5 rows x 26 columns]

# %%
data.tail()
# Out:
#     id first_name last_name  ...  ged english_2nd_language first_generation
# 52 NaN        NaN       NaN  ...  NaN                  NaN              NaN
# 53 NaN        NaN       NaN  ...  NaN                  NaN              NaN
# 54 NaN        NaN       NaN  ...  NaN                  NaN              NaN
# 55 NaN        NaN       NaN  ...  NaN                  NaN              NaN
# 56 NaN        NaN       NaN  ...  NaN                  NaN              NaN
#
# [5 rows x 26 columns]

# %%
# radomly pick any sample
data.sample()
# Out:
#     id first_name last_name  ...  ged english_2nd_language first_generation
# 29 NaN        NaN       NaN  ...  NaN                  NaN              NaN
#
# [1 rows x 26 columns]

# %%
data.sample(3)
# Out:
#     id first_name last_name  ...  ged english_2nd_language first_generation
# 30 NaN        NaN       NaN  ...  NaN                  NaN              NaN
# 48 NaN        NaN       NaN  ...  NaN                  NaN              NaN
# 31 NaN        NaN       NaN  ...  NaN                  NaN              NaN
#
# [3 rows x 26 columns]

# %%
data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'date_of_birth', 'ethnicity', 'gender',
#        'status', 'entry_academic_period', 'exclusion_type', 'act_composite',
#        'act_math', 'act_english', 'act_reading', 'sat_combined', 'sat_math',
#        'sat_verbal', 'sat_reading', 'hs_gpa', 'hs_city', 'hs_state', 'hs_zip',
#        'email', 'entry_age', 'ged', 'english_2nd_language',
#        'first_generation'],
#       dtype='object')

# %%
data['first_name'][:5]
# Out:
# 0     John
# 1     Jane
# 2    Sarah
# 3    Frank
# 4     Mike
# Name: first_name, dtype: object

# %%
data.first_name[:5]
# Out:
# 0     John
# 1     Jane
# 2    Sarah
# 3    Frank
# 4     Mike
# Name: first_name, dtype: object

# %%
type(data['first_name'])
# Out:
# pandas.core.series.Series

# %%
data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'date_of_birth', 'ethnicity', 'gender',
#        'status', 'entry_academic_period', 'exclusion_type', 'act_composite',
#        'act_math', 'act_english', 'act_reading', 'sat_combined', 'sat_math',
#        'sat_verbal', 'sat_reading', 'hs_gpa', 'hs_city', 'hs_state', 'hs_zip',
#        'email', 'entry_age', 'ged', 'english_2nd_language',
#        'first_generation'],
#       dtype='object')

# %%
# first is roes and second is columns
data.iloc[:5,:3]
# Out:
#          id first_name last_name
# 0  111111.0       John       Doe
# 1  111112.0       Jane     Smith
# 2  111113.0      Sarah    Thomas
# 3  111114.0      Frank     Brown
# 4  111115.0       Mike     Davis

# %%
# Extracts all the data from the dataframe in to numpy without
# index and column names
data.values
# Out:
# array([[111111.0, 'John', 'Doe', ..., False, False, True],
#        [111112.0, 'Jane', 'Smith', ..., False, False, True],
#        [111113.0, 'Sarah', 'Thomas', ..., False, False, False],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
type(data.values)
# Out:
# numpy.ndarray

# %%
# Summary of al the numeric columns
data.describe()
# Out:
#                   id  exclusion_type  ...        hs_zip  entry_age
# count       9.000000             0.0  ...      9.000000   9.000000
# mean   111115.000000             NaN  ...  76013.111111  18.422222
# std         2.738613             NaN  ...  25460.751415   0.523874
# min    111111.000000             NaN  ...  10009.000000  17.600000
# 25%    111113.000000             NaN  ...  80012.000000  18.100000
# 50%    111115.000000             NaN  ...  80122.000000  18.500000
# 75%    111117.000000             NaN  ...  85015.000000  18.800000
# max    111119.000000             NaN  ...  98106.000000  19.200000
#
# [8 rows x 12 columns]

# %% [markdown]
# **How far is the data from the mean is standard deviation**

# %%
data.head()
# Out:
#          id first_name last_name  ...    ged english_2nd_language first_generation
# 0  111111.0       John       Doe  ...  False                False             True
# 1  111112.0       Jane     Smith  ...  False                False             True
# 2  111113.0      Sarah    Thomas  ...  False                False            False
# 3  111114.0      Frank     Brown  ...   True                False             True
# 4  111115.0       Mike     Davis  ...  False                 True            False
#
# [5 rows x 26 columns]

# %%
data.id.sum()
# Out:
# 1000035.0

# %%
data.id.mean()
# Out:
# 111115.0

# %%
data.id.count()
# Out:
# 9

# %%
data.shape
# Out:
# (57, 26)

# %%
data['score'] = data['id']*data['entry_age']

# %%
data.head()
# Out:
#          id first_name  ... first_generation      score
# 0  111111.0       John  ...             True  1988886.9
# 1  111112.0       Jane  ...             True  2011127.2
# 2  111113.0      Sarah  ...            False  1955588.8
# 3  111114.0      Frank  ...             True  2111166.0
# 4  111115.0       Mike  ...            False  2022293.0
#
# [5 rows x 27 columns]

# %%
data['score'] = round(data['hs_gpa'],1)

# %%
data.head()
# Out:
#          id first_name last_name  ... english_2nd_language first_generation score
# 0  111111.0       John       Doe  ...                    0             True   2.7
# 1  111112.0       Jane     Smith  ...                    0             True   3.7
# 2  111113.0      Sarah    Thomas  ...                    0            False   2.6
# 3  111114.0      Frank     Brown  ...                    0             True   3.7
# 4  111115.0       Mike     Davis  ...                    0            False   3.5
#
# [5 rows x 27 columns]

# %%
# as the desctibe contains only numerical cols
num_cols = data.describe().columns

# %%
num_data_cols = data[num_cols]

# %%
def convert(x):
  if x==True:
    return 1
  else:
    return 0

# %%
data['english_2nd_language'] = data['english_2nd_language'].apply(convert)

# %%
data.tail()
# Out:
#     id first_name last_name  ... english_2nd_language first_generation score
# 52 NaN        NaN       NaN  ...                    0              NaN   NaN
# 53 NaN        NaN       NaN  ...                    0              NaN   NaN
# 54 NaN        NaN       NaN  ...                    0              NaN   NaN
# 55 NaN        NaN       NaN  ...                    0              NaN   NaN
# 56 NaN        NaN       NaN  ...                    0              NaN   NaN
#
# [5 rows x 27 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     9 non-null      float64
#  1   first_name             9 non-null      object
#  2   last_name              9 non-null      object
#  3   date_of_birth          9 non-null      object
#  4   ethnicity              9 non-null      object
#  5   gender                 9 non-null      object
#  6   status                 9 non-null      object
#  7   entry_academic_period  9 non-null      object
#  8   exclusion_type         0 non-null      float64
#  9   act_composite          5 non-null      float64
#  10  act_math               5 non-null      float64
#  11  act_english            6 non-null      object
#  12  act_reading            5 non-null      float64
#  13  sat_combined           2 non-null      float64
# ...

# %% [markdown]
# **Seaborn**
#
# ---

# %%
import seaborn as sns
print(sns.__version__)
# Out:
# 0.11.0

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %%
 tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
num_cols = tips.describe().columns

# %%
tips['sex'].describe()
# Out:
# count      244
# unique       2
# top       Male
# freq       157
# Name: sex, dtype: object

# %%
tips['sex'].unique()
# Out:
# ['Female', 'Male']
# Categories (2, object): ['Female', 'Male']

# %%
tips['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %% [markdown]
# ### Distplot
# This shows the distribution of a univariate set of observations.
#
# - Univariate is a term commonly used in statistics to describe a type of data which consists of observations on only a single characteristic or attribute.

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.distplot(tips['total_bill'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Pairplot
# It plots the pairwise relationships accross an entire dataframe.
# But this is done only for the numerical data.

# %%
sns.pairplot(tips)

# %%
tips.describe().columns
# Out:
# Index(['total_bill', 'tip', 'size'], dtype='object')

# %% [markdown]
#  It shows the relationship between a numeric and a categoric variable.

# %%
sns.barplot(x='sex', y='total_bill',data=tips)

# %%
import matplotlib.pyplot as plt
sns.barplot(x='sex', y='tip',data=tips)
plt.xticks(rotation=60)
# Out:
# (array([0, 1]), <a list of 2 Text major ticklabel objects>)

# %% [markdown]
# ### Boxplot
#
# It is used to show the distribution of a categorical data.
# - It is also called as box-and-whisker plot
# - It helps to identify the outliers
#
# - A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable.
# - The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.

# %%
tips['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sns.boxplot(x='day', y='total_bill',data=tips)
